# %%
import polars as pl
import polars.selectors as cs
from polars.exceptions import ColumnNotFoundError
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['timezone'] = 'Europe/Moscow'

from datetime import datetime, timezone, timedelta
from zoneinfo import ZoneInfo
import pickle
import json
from tqdm.notebook import tqdm
from itertools import product
import random

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV, cross_val_predict
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, root_mean_squared_error, roc_auc_score

import catboost as cb
from catboost import Pool, cv

from bot.core.db.postgres_manager import DBManager
from bot.config.credentials import host, user, password, db_name
db_params = {'host': host, 'user': user, 'password': password, 'dbname': db_name}
db_manager = DBManager(db_params)

from bot.analysis.backtesting import backtest
from bot.utils.pair_trading import *
from bot.analysis.strategy_analysis import analyze_strategy
from bot.utils.files import load_config

with open("./data/coin_information.pkl", "rb") as f:
     coin_information = pickle.load(f)

# %% [markdown]
# #### Создание датасета

# %%
def run_test(df, wind, in_, out_, open_method, dist_in, dist_out, force_close):
    cols = ['time', 'ts', token_1, f'{token_1}_bid_price', f'{token_1}_ask_price',
            f'{token_1}_bid_size', f'{token_1}_ask_size', token_2,
            f'{token_2}_bid_price', f'{token_2}_ask_price', f'{token_2}_bid_size', f'{token_2}_ask_size',
            f'spread_{wind}_{tf}', f'spread_mean_{wind}_{tf}', f'spread_std_{wind}_{tf}', f'z_score_{wind}_{tf}']

    tdf = df.select(cols).rename({f'z_score_{wind}_{tf}': 'z_score', f'spread_{wind}_{tf}': 'spread',
                f'spread_mean_{wind}_{tf}': 'spread_mean', f'spread_std_{wind}_{tf}': 'spread_std'}).drop_nulls()

    trades_df = backtest(tdf, token_1, token_2, dp_1, dp_2,
            thresh_low_in=-in_, thresh_low_out=-out_, thresh_high_in=in_, thresh_high_out=out_,
            long_possible=True, short_possible=True,
            balance=100, order_size=50, qty_method=qty_method, std_1=std_1, std_2=std_2,
            fee_rate=0.001, sl_std=sl_std, sl_dist=1.0, sl_method='leave',
            sl_seconds = 60, open_method=open_method, close_method=close_method, 
            leverage=leverage, dist_in=dist_in, dist_out=dist_out, force_close=force_close,
            verbose=0)

    if trades_df.height > 1:
        metrics = analyze_strategy(trades_df, start_date=valid_time, end_date=end_date, initial_balance=100.0)
        return tdf, trades_df, metrics
    else:
        return tdf, pl.DataFrame(), dict()

# %%
def get_coins_info(token_1, token_2):
    dp_1 = float(coin_information['bybit_linear'][token_1 + '_USDT']['qty_step'])
    ps_1 = int(coin_information['bybit_linear'][token_1 + '_USDT']['price_scale'])
    dp_2 = float(coin_information['bybit_linear'][token_2 + '_USDT']['qty_step'])
    ps_2 = int(coin_information['bybit_linear'][token_2 + '_USDT']['price_scale'])

    return dp_1, dp_2, ps_1, ps_2

# %%
pairs_file = './data/token_pairs.txt'

all_pairs = pl.read_parquet('./data/pair_selection/all_pairs.parquet')

with open("./data/coin_information.pkl", "rb") as f:
    coin_information = pickle.load(f)

token_pairs = []
with open(pairs_file, 'r') as file:
    for line in file:
        a, b = line.strip().split()
        token_pairs.append((a, b))
len(token_pairs)

# %%
# Параметры
config = load_config('./bot/config/config.yaml')
valid_time = config['valid_time']
end_time = config['end_time']
force_close = False
qty_method = 'usdt_neutral'

leverage = 2
min_order_size = 42
max_order_size = 50
fee_rate = 0.001
sl_ratio = 0.1
sl_std = 8.0
close_method = 'direct'

tf = '1h'
winds = (72,)

# open_methods = ('direct', 'reverse_static', 'reverse_dynamic')
in_min = 1.6
in_max = 2.75
out_min = 0.0
out_max = 0.75
dist_min = 0.05
dist_max = 1.0

spr_method = 'lr'

metrics_arr = []

# %%
in_ = 2.0
out_ = 0.1
dist_in = 0.5
dist_out = 0.0
wind = 72
open_method = 'reverse_static'
hours_back = 2

# %%
# n_iters = 10_000

# for _ in tqdm(range(n_iters)):
for token_1, token_2 in tqdm(token_pairs):
    # token_1, token_2 = random.choice(token_pairs)
    pair_stats = all_pairs.filter((pl.col('coin1') == token_1) & (pl.col('coin2') == token_2))

    if pair_stats.height > 0:
        std_1 = pair_stats['std_1'][0]
        std_2 = pair_stats['std_2'][0]
    else:
        print(token_1, token_2, 'No Stats Data!')
        continue

    # file_dist = f'./data/pair_backtest/{token_1}_{token_2}_1h_dist.parquet'
    file_lr = f'./data/pair_backtest/{token_1}_{token_2}_1h_lr.parquet'

    try:
        df = pl.read_parquet(file_lr, low_memory=True, rechunk=True, use_pyarrow=True)
        end_date = df['time'][-1]
    except FileNotFoundError:
        print(f'FileNotFoundError!: {filepath}')
        continue

    # in_ = round(random.uniform(in_min, in_max), 2)
    # out_ = round(random.uniform(out_min, out_max), 2)
    # wind = random.choice(winds)
    # open_method = random.choice(open_methods)

    dp_1, dp_2, ps_1, ps_2 = get_coins_info(token_1, token_2)

    # if open_method == 'direct':
    #     dist_in = 0.0
    #     dist_out = 0.0
    # elif open_method in ('reverse_static', 'reverse_dynamic'):
    # dist_in = round(random.uniform(dist_min, dist_max), 2)
    # dist_out = round(random.uniform(dist_min, dist_max), 2)

    tdf, trades_df, metrics = run_test(df, wind, in_, out_, open_method, dist_in, dist_out, force_close)

    tick_df, agg_df = load_data(token_1, token_2, valid_time, end_time, tf, max(winds), db_manager)
    tick_df = tick_df.drop_nulls()
    

    # tick_df = tick_df.with_columns((pl.col(token_1).log() - pl.col(token_2).log()).alias('log_spread'))
    # agg_df = agg_df.with_columns((pl.col(token_1).log() - pl.col(token_2).log()).alias('log_spread'))
    
    for trade in trades_df.to_dicts():
        open_time = trade['open_time']
        side_1 = 'long' if trade['pos_side'] == 1 else 'short'
        side_2 = 'long' if trade['pos_side'] == 2 else 'short'
    
        try:
            stats = get_open_time_stats(token_1, token_2, side_1, open_time, hours_back, coin_information, db_manager)
        except IndexError:
            continue
    
        duration = (trade['close_ts'] - trade['open_ts']) / 3600
        trade.pop('open_time')
        trade.pop('close_time')
        trade.pop('open_ts')
        trade.pop('close_ts')
        pars = {'token_1': token_1, 'token_2': token_2, 'spr_method': spr_method, 'wind': wind, 
                'in_': in_, 'out_': out_, 'open_method': open_method, 'dist_in': dist_in, 'dist_out': dist_out,
               'duration': duration}
        
        log = pars | trade | stats
        json_log = json.dumps(log, default=float, ensure_ascii=False)
        with open('./logs/backtest_trades.jsonl', 'a', encoding='utf-8') as f:
            f.write(json_log + '\n')
    
        metrics_arr.append(log)

# %% [markdown]
# #### ML

# %%
test_tokens = [('RUNE', 'STX'), ('RUNE', 'WIF'), ('IMX', 'XTZ'), ('RUNE', 'THETA'), ('INJ', 'ORDI'), ('THETA', 'WIF'),
 ('DRIFT', 'OP'), ('HBAR', 'SEI'), ('APT', 'ATOM'), ('EIGEN', 'SPX'), ('IMX', 'RUNE'), ('JUP', 'XTZ'), ('EIGEN', 'PENDLE'),
 ('AERO', 'ENA'), ('IMX', 'JUP'), ('CRV', 'DYDX'), ('ARB', 'DOGE'), ('ARKM', 'STX'), ('WLD', 'XTZ'), ('INJ', 'PENDLE'),
 ('ARB', 'CELO'), ('STX', 'XLM'), ('ATOM', 'ORDI'), ('DOT', 'WLD'), ('FLOW', 'HBAR'), ('TON', 'ZRO'), ('ATOM', 'PENDLE'),
 ('JUP', 'S')]

# %%
trades = pl.read_ndjson('./logs/backtest_trades.jsonl')
# trades = trades.to_dummies(columns=["open_method", "spr_method"]).drop('spr_method_lr', 'open_method_reverse_static'
#             ).rename({'spr_method_dist': 'spr_method', 'open_method_direct': 'om_dir', 'open_method_reverse_dynamic': 'om_rd'})

trades = trades.with_columns(
    pl.col("reason").replace({1: 0, 2: 1})
)

# %%
# trades = trades.filter(pl.col('pos_side') == 2)

# %%
# Отфильтруем те сделки, которые были в реальной жизни, чтобы потом на них проверить модель,
# и создадим датафрейм только для тех пар, которые не торговались в реале
pairs_df = pl.DataFrame(test_tokens, schema=["token_1","token_2"], orient='row')
test_df = trades.join(pairs_df, on=["token_1","token_2"])
main_df = trades.join(pairs_df, on=["token_1","token_2"], how="anti")

# %%
print('Размер датасета:', main_df.height)
print('Распределение профита на всём датасете.')
print(f'min: {main_df['total_profit'].min():.1f}$; max: {main_df['total_profit'].max():.1f}$', end=', ')
print(f'mean: {main_df['total_profit'].mean():.1f}$, median: {main_df['total_profit'].median():.1f}$', end=', ')
print(f'SUM: {main_df['total_profit'].sum():.1f}$; std: {main_df['total_profit'].std():.2f}$')
# Out:
# Размер датасета: 5897
# Распределение профита на всём датасете.
# min: -12.7$; max: 18.8$, mean: -0.2$, median: 0.4$, SUM: -893.6$; std: 3.27$

# %%
# Размер датасета: 3273
# Распределение профита на всём датасете.
# min: -28.4$; max: 21.6$, mean: 0.1$, median: 0.6$, SUM: 487.1$; std: 3.43$

# %%
features = ['total_profit', 'reason', 'rsi_long']

# %%
cols_to_drop = ['token_1', 'token_2', 'fees', 'qty_1', 'qty_2', 'profit_1', 'profit_2', 'open_price_1', 'open_price_2',
                'close_price_1', 'close_price_2', 'long_std_wind', 'short_std_wind', 
                'long_std_hb', 'short_std_hb', 'open_method', 'spr_method', 'duration']

# %%
def prepare_stats(trades, bad_cols):
    return trades.drop(bad_cols)

# %%
stats_df = prepare_stats(main_df, cols_to_drop)
stat_schema = stats_df.schema

# %%
def get_train_test_split(main_df, seed):
    # 1. Get all unique token pairs and sort for stability
    unique_pairs = (
        main_df
        .select(["token_1", "token_2"])
        .unique()
        .sort(["token_1", "token_2"])  # Ensures consistent ordering
    )
    
    # 2. Create a deterministic random number for each pair
    #    pl.col("token_1").hash() creates a hash based on the column's values[citation:7].
    unique_pairs = unique_pairs.with_columns(
        (
            (pl.col("token_1").hash(seed=seed) + pl.col("token_2").hash(seed=seed)) % 100 / 100.0
        ).alias("rand_num")
    )
    
    # 3. Split pairs based on the deterministic hash
    train_pairs = unique_pairs.filter(pl.col("rand_num") <= 0.8).select(["token_1", "token_2"])
    test_pairs = unique_pairs.filter(pl.col("rand_num") > 0.8).select(["token_1", "token_2"])
    
    # 4. Create the final train and test DataFrames
    train_df = main_df.join(train_pairs, on=["token_1", "token_2"], how="inner")
    test_df = main_df.join(test_pairs, on=["token_1", "token_2"], how="inner")

    return train_df, test_df

# %%
train_df, test_df = get_train_test_split(main_df, 5)

# %%
train_df = prepare_stats(train_df, cols_to_drop)
test_df = prepare_stats(test_df, cols_to_drop)

# %%
print(f"Размер train_df: {train_df.height} строк")
print(f"Размер test_df: {test_df.height} строк")
# Out:
# Размер train_df: 4699 строк
# Размер test_df: 1198 строк

# %%
profit_threshold = 0.5

X_train = train_df.drop('total_profit', 'reason').to_pandas()
X_test = test_df.drop('total_profit', 'reason').to_pandas()

y_profit_train = train_df.select('total_profit').to_numpy().ravel()
y_profit_test = test_df.select('total_profit').to_numpy().ravel()

y_sl_train = train_df.select('reason').to_numpy().ravel()
y_sl_test = test_df.select('reason').to_numpy().ravel()

y_good_profit_train = (train_df.select('total_profit').to_numpy() > profit_threshold).astype(int).ravel()
y_good_profit_test = (test_df.select('total_profit').to_numpy() > profit_threshold).astype(int).ravel()

# %%
sl_train = np.unique_counts(y_sl_train).counts[1]
sl_test = np.unique_counts(y_sl_test).counts[1]

print('Распределение профита на тренировочном и тестовом датасете, а также доля стоп-лоссов')
print(f'train ({len(X_train)} записей). min: {y_profit_train.min():.2f}$; max: {y_profit_train.max():.2f}$', end=', ')
print(f'mean: {y_profit_train.mean():.2f}$, median: {np.median(y_profit_train):.2f}$', end=', ')
print(f'std: {y_profit_train.std():.2f}$; stop losses: {sl_train:>3} ({sl_train / len(y_sl_train):.3f})')

print(f'test  ({len(X_test)} записей).  min: {y_profit_test.min():.2f}$; max: {y_profit_test.max():.2f}$', end=', ')
print(f'mean: {y_profit_test.mean():.2f}$, median: {np.median(y_profit_test):.2f}$', end=', ')
print(f'std: {y_profit_test.std():.2f}$; stop losses: {sl_test:>3} ({sl_test / len(y_sl_test):.3f})')
# Out:
# Распределение профита на тренировочном и тестовом датасете, а также доля стоп-лоссов
# train (4699 записей). min: -12.54$; max: 16.93$, mean: -0.15$, median: 0.35$, std: 3.27$; stop losses: 280 (0.060)
# test  (1198 записей).  min: -12.74$; max: 18.84$, mean: -0.14$, median: 0.49$, std: 3.28$; stop losses:  87 (0.073)

# %%
# X_train = np.random.rand(1814, 4)
# X_test = np.random.rand(447, 4)

# %%
# cbr.save_model('./data/catboost_model.json', format='json')

# %%
# Классификация стоп-лоссов
cv_clf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

clf_sl_model = cb.CatBoostClassifier(random_seed=42, verbose=False)
# clf_sl_model = cb.CatBoostClassifier(random_state=42, verbose=False, **best_clf_params)

clf_sl_model.fit(X_train, y_sl_train);
sl_preds = clf_sl_model.predict_proba(X_test)[:, 1]

# %%
cv_scores = cross_val_score(clf_sl_model, X_train, y_sl_train, cv=cv_clf, scoring='roc_auc')
cv_mean = cv_scores.mean()
cv_std = cv_scores.std()
score_test = roc_auc_score(y_sl_test, sl_preds)

# %%
print(f'ROC-AUC на кросс-валидации. Mean: {cv_mean:.4f}, Std: {cv_std:.4f}')
print(f"ROC-AUC на тестовом датасете. {score_test:.4f}")
# Out:
# ROC-AUC на кросс-валидации. Mean: 0.7382, Std: 0.0405
# ROC-AUC на тестовом датасете. 0.7213

# %%
# С реальными фичами (Long + Short)
# ROC-AUC на кросс-валидации. Mean: 0.7382, Std: 0.0405
# ROC-AUC на тестовом датасете. 0.7213

# %%
# С помощью кросс-валидации предскажем, случится ли стоп-лосс на тренировочной выборке
# sl_pred_train = cross_val_predict(clf_sl_model, X_train, y_clf_train, cv=cv_clf, method='predict_proba', n_jobs=-1)[:, 1]

# %%
# Добавляем предсказание стоп-лосса в тренировочную и тестовую выборки
# X_train_sl = np.hstack((X_train, sl_pred_train.reshape(-1, 1)))
# X_test_sl = np.hstack((X_test, sl_preds.reshape(-1, 1)))
# print(f"Новая размерность X_train: {X_train_sl.shape}")

# %%
# %%time
regr_model = cb.CatBoostRegressor(random_seed=42, verbose=False)
regr_model.fit(X_train, y_profit_train);
profit_preds = regr_model.predict(X_test)
regr_score_test = root_mean_squared_error(y_profit_test, profit_preds)

cv_regr_scores = cross_val_score(regr_model, X_train, y_profit_train, cv=5, scoring='neg_root_mean_squared_error')
regr_mean = abs(cv_regr_scores.mean())
regr_std = cv_regr_scores.std()
# Out:
# CPU times: total: 8min 44s
# Wall time: 18.6 s

# %%
print(f'RMSE на кросс-валидации. Mean: {regr_mean:.4f}, Std: {regr_std:.4f}')
print(f"RMSE на тестовом датасете. {regr_score_test:.4f}")
# Out:
# RMSE на кросс-валидации. Mean: 3.0605, Std: 0.1909
# RMSE на тестовом датасете. 3.0859

# %%
# Реальные фичи (Long + Short)
# RMSE на кросс-валидации. Mean: 3.0605, Std: 0.1909
# RMSE на тестовом датасете. 3.0859

# %%
# Классификация профита > 0.5
cbr_pr_clf = cb.CatBoostClassifier(random_seed=42, verbose=False)
cbr_pr_clf.fit(X_train, y_good_profit_train);
cbr_pr_clf_pred_proba = cbr_pr_clf.predict_proba(X_test)[:, 1]
gp_clf_score = roc_auc_score(y_good_profit_test, cbr_pr_clf_pred_proba)

# %%
cv_pr_clf_scores = cross_val_score(cbr_pr_clf, X_train, y_good_profit_train, cv=cv_clf, scoring='roc_auc')
gp_clf_mean = cv_pr_clf_scores.mean()
gp_clf_std = cv_pr_clf_scores.std()

# %%
print(f'ROC-AUC на кросс-валидации. Mean: {gp_clf_mean:.4f}, Std: {gp_clf_std:.4f}')
print(f"ROC-AUC на тестовом датасете. {gp_clf_score:.4f}")
# Out:
# ROC-AUC на кросс-валидации. Mean: 0.6762, Std: 0.0253
# ROC-AUC на тестовом датасете. 0.6851

# %%
# (Long + Short)
# ROC-AUC на кросс-валидации. Mean: 0.6762, Std: 0.0253
# ROC-AUC на тестовом датасете. 0.6851

# %% [markdown]
# #### Подбор параметров модели

# %%
import optuna

# %%
def objective_clf(trial):
    # Задаем пространство поиска параметров
    param = {
        'iterations': trial.suggest_int('iterations', 200, 2000),
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),
        'silent': True,
        'allow_writing_files': False, # Чтоб не мусорить логами
        'random_seed': 42
    }

    model = cb.CatBoostRegressor(**param)
    # cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_profit_train, cv=5, scoring='neg_root_mean_squared_error', n_jobs=-1)
    
    return scores.mean()

# %%
study_clf = optuna.create_study(direction='maximize')
# Out:
# [I 2025-12-13 23:22:38,587] A new study created in memory with name: no-name-a7899312-b37e-4823-9eb0-181b7e42a1c1

# %%
study_clf.optimize(objective_clf, n_trials=50)
# Out:
# [I 2025-12-13 23:22:42,732] Trial 0 finished with value: -3.09335288525683 and parameters: {'iterations': 615, 'depth': 4, 'learning_rate': 0.059208154196225785, 'l2_leaf_reg': 0.7827955465007499, 'subsample': 0.5837586032220086, 'colsample_bylevel': 0.8370605060198979}. Best is trial 0 with value: -3.09335288525683.
# [I 2025-12-13 23:22:53,228] Trial 1 finished with value: -3.1274023974053726 and parameters: {'iterations': 1578, 'depth': 5, 'learning_rate': 0.14238524826712157, 'l2_leaf_reg': 0.30191672212541604, 'subsample': 0.5622062401577131, 'colsample_bylevel': 0.5099067211209731}. Best is trial 0 with value: -3.09335288525683.
# [I 2025-12-13 23:23:45,422] Trial 2 finished with value: -3.1352929217748575 and parameters: {'iterations': 1159, 'depth': 8, 'learning_rate': 0.11596110756478396, 'l2_leaf_reg': 0.018798873198649636, 'subsample': 0.5798858532907242, 'colsample_bylevel': 0.5628466611887182}. Best is trial 0 with value: -3.09335288525683.
# ...

# %%
print("Лучшие параметры классификатора:", study_clf.best_params)

# %%
best_clf_params = study_clf.best_params

# %%
study_clf.best_value

# %%
def test(df, std_ratio_5m):

# %%
pl.DataFrame(X_train)#.select('std_ratio_5m')
# Out:
# shape: (4_699, 127)
# ┌─────────┬─────────┬─────────┬─────────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ lr_spr_ ┆ z_fz_co ┆ trend_w ┆ neg_sen ┆ … ┆ spread_ ┆ spread_ ┆ spread_ ┆ spread_ │
# │ median  ┆ rr      ┆ ind     ┆ s_mean  ┆   ┆ rsi_20  ┆ rsi_25  ┆ rsi_30  ┆ rsi_40  │
# │ ---     ┆ ---     ┆ ---     ┆ ---     ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ f64     ┆ f64     ┆ f64     ┆ f64     ┆   ┆ bool    ┆ bool    ┆ bool    ┆ bool    │
# ╞═════════╪═════════╪═════════╪═════════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ 0.00405 ┆ 0.99735 ┆ -2.2394 ┆ -0.5852 ┆ … ┆ false   ┆ false   ┆ false   ┆ false   │
# │ 4       ┆ 5       ┆ 28      ┆ 7       ┆   ┆         ┆         ┆         ┆         │
# │ -0.0088 ┆ 0.97442 ┆ -1.0975 ┆ 0.32395 ┆ … ┆ false   ┆ false   ┆ false   ┆ false   │
# │ 01      ┆ 4       ┆ 54      ┆ 2       ┆   ┆         ┆         ┆         ┆         │
# │ -0.0195 ┆ 0.93990 ┆ -2.6369 ┆ 0.01164 ┆ … ┆ false   ┆ false   ┆ false   ┆ false   │
# ...

# %% [markdown]
# #### Test

# %%
cols = stats_df.drop('total_profit', 'reason').columns# + ['reason_pred']

# %%
len(clf_sl_model.feature_importances_)

# %%
feature_importance = pl.DataFrame({
    'feature': cols,
    'reg_importance': regr_model.feature_importances_,
    'clf_sl_importance': clf_sl_model.feature_importances_,
    'clf_pr_importance': cbr_pr_clf.feature_importances_
})
feature_importance.sort(by='clf_pr_importance', descending=True)

# %%
test_df = pl.DataFrame(X_test, schema=stats_df.drop('total_profit', 'reason').columns, orient='row').with_columns(
        pl.Series('total_profit', y_profit_test),
        pl.Series('reason', y_sl_test),
        pl.Series('reason_pred', sl_preds),
        pl.Series('profit_pred', profit_preds),
        pl.Series('good_profit_pred', cbr_pr_clf_pred_proba),
    
    )

# %%
test_df.select('in_', 'out_', 'reason', 'total_profit', 'reason_pred', 'profit_pred', 'good_profit_pred').sample(5)

# %%
pos_trades = test_df.filter(pl.col('total_profit') > 0)
n_pos_trades = pos_trades.height / test_df.height
neg_trades = test_df.filter(pl.col('total_profit') < 0)
n_neg_trades = neg_trades.height / test_df.height
base_profit = test_df['total_profit'].sum()
n_sl = test_df.filter(pl.col('reason') == 1).height

print(f'Всего сделок: {test_df.height}, плюсовых: {pos_trades.height} ({n_pos_trades:.2f})', end=', ')
print(f'минусовых: {neg_trades.height} ({n_neg_trades:.2f}); profit: ${base_profit:.2f}', end='; ')
print(f'stop-losses: {n_sl} ({n_sl / test_df.height:.2f})')

# %%
# Long + Short.
# Всего сделок: 1198, плюсовых: 714 (0.60), минусовых: 484 (0.40); profit: $-169.38; stop-losses: 87 (0.07)

# Long only
# Всего сделок: 567, плюсовых: 322 (0.57), минусовых: 245 (0.43); profit: $-250.50; stop-losses: 45 (0.08)

# Short only
# Всего сделок: 631, плюсовых: 392 (0.62), минусовых: 239 (0.38); profit: $81.12; stop-losses: 42 (0.07)

# %%
sl_df = test_df.filter(pl.col('reason_pred') < 0.05)
pos_trades = sl_df.filter(pl.col('total_profit') > 0)
n_pos_trades = pos_trades.height / sl_df.height
neg_trades = sl_df.filter(pl.col('total_profit') < 0)
n_neg_trades = neg_trades.height / sl_df.height

sl_profit = sl_df['total_profit'].sum()
n_sl = sl_df.filter(pl.col('reason') == 1).height

print(f'Отсеиваем сделки с вероятностью stop-loss больше 5%')
print(f'Всего сделок: {sl_df.height}, плюсовых: {pos_trades.height} ({n_pos_trades:.2f})', end=', ')
print(f'минусовых: {neg_trades.height} ({n_neg_trades:.2f}); profit: ${sl_profit:.2f}', end='; ')
print(f'stop-losses: {n_sl} ({n_sl / sl_df.height:.2f})')

# %%
# Long + Short:
# Всего сделок: 947, плюсовых: 574 (0.61), минусовых: 373 (0.39); profit: $70.71; stop-losses: 43 (0.05)

# Long only
# Всего сделок: 472, плюсовых: 267 (0.57), минусовых: 205 (0.43); profit: $-121.84; stop-losses: 27 (0.06)

# Short only
# Всего сделок: 543, плюсовых: 340 (0.63), минусовых: 203 (0.37); profit: $148.70; stop-losses: 23 (0.04)

# Summary. Всего сделок: 1015, profit: 26.86; stop losses: 50

# %%
profit_pred_df = test_df.filter(pl.col('profit_pred') > 0.0)
pos_trades = profit_pred_df.filter(pl.col('total_profit') > 0)
n_pos_trades = pos_trades.height / profit_pred_df.height
neg_trades = profit_pred_df.filter(pl.col('total_profit') < 0)
n_neg_trades = neg_trades.height / profit_pred_df.height

pred_profit = profit_pred_df['total_profit'].sum()
n_sl = profit_pred_df.filter(pl.col('reason') == 1).height

print(f'Отсеиваем сделки с предсказанным профитом меньше 0')
print(f'Всего сделок: {profit_pred_df.height}, плюсовых: {pos_trades.height} ({n_pos_trades:.2f})', end=', ')
print(f'минусовых: {neg_trades.height} ({n_neg_trades:.2f}); profit: ${pred_profit:.2f}', end='; ')
print(f'stop-losses: {n_sl} ({n_sl / profit_pred_df.height:.2f})')

# %%
# Отсеиваем сделки с предсказанным профитом меньше 0
# Всего сделок: 507, плюсовых: 356 (0.70), минусовых: 151 (0.30); profit: $313.52; stop-losses: 27 (0.05)

# Long only
# Всего сделок: 210, плюсовых: 135 (0.64), минусовых: 75 (0.36); profit: $58.51; stop-losses: 12 (0.06)

# Short only
# Всего сделок: 303, плюсовых: 228 (0.75), минусовых: 75 (0.25); profit: $254.99; stop-losses: 14 (0.05)

# Summary. Всего сделок: 513; profit: +313.5; stop losses: 26

# %%
gp_pred_df = test_df.filter(pl.col('good_profit_pred') > 0.5)
pos_trades = gp_pred_df.filter(pl.col('total_profit') > 0)
n_pos_trades = pos_trades.height / gp_pred_df.height
neg_trades = gp_pred_df.filter(pl.col('total_profit') < 0)
n_neg_trades = neg_trades.height / gp_pred_df.height

gp_profit = gp_pred_df['total_profit'].sum()
n_sl = gp_pred_df.filter(pl.col('reason') == 1).height

print(f'Отсеиваем сделки с предсказанным профитом меньше 0.5')
print(f'Всего сделок: {gp_pred_df.height}, плюсовых: {pos_trades.height} ({n_pos_trades:.2f})', end=', ')
print(f'минусовых: {neg_trades.height} ({n_neg_trades:.2f}); profit: ${gp_profit:.2f}', end='; ')
print(f'stop-losses: {n_sl} ({n_sl / gp_pred_df.height:.2f})')

# %%
# Отсеиваем сделки с предсказанным профитом меньше 0.5
# Всего сделок: 521, плюсовых: 367 (0.70), минусовых: 154 (0.30); profit: $235.53; stop-losses: 38 (0.07)

# Long only
# Всего сделок: 227, плюсовых: 148 (0.65), минусовых: 79 (0.35); profit: $17.91; stop-losses: 19 (0.08)

# Short only
# Всего сделок: 298, плюсовых: 226 (0.76), минусовых: 72 (0.24); profit: $246.37; stop-losses: 17 (0.06)

# Summary. Всего сделок: 525; profit: +264.28; stop losses: 36

# %%
# Long + Short: -17.94
test_df.filter(pl.col('good_profit_pred') > 0.5)['total_profit'].min()

# %% [markdown]
# #### Проверка реальностью

# %%
def calculate_stats(data):
    price_ratio = data['open_price_1'] / data['open_price_2']
    std_wind_ratio = data['long_std_wind'] / data['short_std_wind'] - 1
    std_hb_ratio = data['long_std_hb'] / data['short_std_hb'] - 1
    price_ratio_0_25 = price_ratio < 0.25
    price_ratio_0_5 = price_ratio < 0.5
    price_ratio_0_75 = price_ratio < 0.75
    price_ratio_1_0 = price_ratio < 1.0
    price_ratio_1_25 = price_ratio < 1.25
    price_ratio_1_5 = price_ratio < 1.5
    price_ratio_2_0 = price_ratio < 2.0
    price_ratio_2_5 = price_ratio < 2.5
    std_wind_ratio_0_25 = std_wind_ratio < 0.25
    std_wind_ratio_0_5 = std_wind_ratio < 0.5
    std_wind_ratio_1_0 = std_wind_ratio < 1.0
    std_hb_ratio_0_25 = std_hb_ratio < 0.25
    std_hb_ratio_0_5 = std_hb_ratio < 0.5
    std_hb_ratio_1_0 = std_hb_ratio < 1.0
    spread_rsi_20 = data['spread_rsi'] < 20
    spread_rsi_25 = data['spread_rsi'] < 25
    spread_rsi_30 = data['spread_rsi'] < 30
    spread_rsi_40 = data['spread_rsi'] < 40

    d = {
        'trend_hb': data['trend_hb'],
        'trend_wind': data['trend_wind'],
        'rsi_long': data['rsi_long'],
        'bid_usdt_mean_wind': data['bid_usdt_mean_wind'],
        'spread_rsi': data['spread_rsi'],
        'profit_z_corr': data['profit_z_corr'],
        'bid_5m_wind_ratio': data['bid_5m_wind_ratio'],
        'out_': data['out_'],
        'z_score_median': data['z_score_median'],
        'in_': data['in_'],
        'spr_mean': data['spr_mean'],
        'ask_5m_hb_ratio': data['ask_5m_hb_ratio'],
        'bid_5m_hb_ratio': data['bid_5m_hb_ratio'],
        'z_score_dist_from_max': data['z_score_dist_from_max'],
        'z_score_dist_from_median': data['z_score_dist_from_median'],
        'z_score_5m_d': data['z_score_5m_d'],
        'z_score_min_d': data['z_score_min_d'],
        'z_score_mean_d': data['z_score_mean_d'],
        'z_score_dist_to_target_d': data['z_score_dist_to_target_d'],
        'z_score_dist_from_median_d': data['z_score_dist_from_median_d'],
        'z_score_5m_change_d': data['z_score_5m_change_d'],
        'tls_beta_hb': data['tls_beta_hb'],
        'half_life_log_spread': data['half_life_log_spread'],
        'half_life_z_score': data['half_life_z_score'],
        'half_life_lr_z_score': data['half_life_lr_z_score'],
        'reason': None,
        'profit_sens_fav': data['profit_sens_fav'],
        'wind': data['wind'],
        'mean_hb': data['mean_hb'],
        'ask_usdt_mean_wind': data['ask_usdt_mean_wind'],
        'ask_usdt_mean_hb': data['ask_usdt_mean_hb'],
        'ask_usdt_mean_5m': data['ask_usdt_mean_5m'],
        'bid_usdt_mean_5m': data['bid_usdt_mean_5m'],
        'dist_in': data['dist_in'],
        'rsi_short': data['rsi_short'],
        'bid_hb_wind_ratio': data['bid_hb_wind_ratio'],
        'z_score_hb': data['z_score_hb'],
        'z_score_dist_to_target': data['z_score_dist_to_target'],
        'z_score_hb_change': data['z_score_hb_change'],
        'z_score_median_d': data['z_score_median_d'],
        'z_score_max_dist_d': data['z_score_max_dist_d'],
        'mean_diff': data['mean_diff'],
        'tls_beta_wind': data['tls_beta_wind'],
        'profit_sens_adv': data['profit_sens_adv'],
        'z_score_max_dist': data['z_score_max_dist'],
        'z_score_dist_from_mean_d': data['z_score_dist_from_mean_d'],
        'dist_out': data['dist_out'],
        'ask_hb_wind_ratio': data['ask_hb_wind_ratio'],
        'profit_fz_corr': data['profit_fz_corr'],
        'z_score_min': data['z_score_min'],
        'z_score_5m_change': data['z_score_5m_change'],
        'bid_ask_ratio_wind': data['bid_ask_ratio_wind'],
        'z_fz_corr': data['z_fz_corr'],
        'bid_ask_ratio_hb': data['bid_ask_ratio_hb'],
        'ask_5m_wind_ratio': data['ask_5m_wind_ratio'],
        'z_score_curr': data['z_score_curr'],
        'z_score_max': data['z_score_max'],
        'z_score_curr_d': data['z_score_curr_d'],
        'z_score_dist_from_max_d': data['z_score_dist_from_max_d'],
        'z_score_dist_from_mean': data['z_score_dist_from_mean'],
        'z_score_hb_change_d': data['z_score_hb_change_d'],
        'z_score_5m': data['z_score_5m'],
        'pos_side': data['pos_side'],
        'z_score_hb_d': data['z_score_hb_d'],
        'z_score_mean': data['z_score_mean'],
        'bid_ask_ratio_5m': data['bid_ask_ratio_5m'],
        'total_profit': None,
        'bid_usdt_mean_hb': data['bid_usdt_mean_hb'],
        'pr_fz_change': data['pr_fz_change'],
        'z_score_max_d': data['z_score_max_d'],
        'hurst_wind': data['hurst_wind'],
        'pr_z_change': data['pr_z_change'],
        'price_ratio': price_ratio,
        'std_wind_ratio': std_wind_ratio,
        'std_hb_ratio': std_hb_ratio,

        'price_ratio_0.25': price_ratio_0_25,
        'price_ratio_0.5': price_ratio_0_5,
        'price_ratio_0.75': price_ratio_0_75,
        'price_ratio_1.0': price_ratio_1_0,
        'price_ratio_1.25': price_ratio_1_25,
        'price_ratio_1.5': price_ratio_1_5,
        'price_ratio_2.0': price_ratio_2_0,
        'price_ratio_2.5': price_ratio_2_5,
        'std_wind_ratio_0.25': std_wind_ratio_0_25,
        'std_wind_ratio_0.5': std_wind_ratio_0_5,
        'std_wind_ratio_1.0': std_wind_ratio_1_0,
        'std_hb_ratio_0.25': std_hb_ratio_0_25,
        'std_hb_ratio_0.5': std_hb_ratio_0_5,
        'std_hb_ratio_1.0': std_hb_ratio_1_0,
        'spread_rsi_20': spread_rsi_20,
        'spread_rsi_25': spread_rsi_25,
        'spread_rsi_30': spread_rsi_30,
        'spread_rsi_40': spread_rsi_40,

        'spr_min': data['spr_min'], 
        'spr_max': data['spr_max'], 
        'spr_median': data['spr_median'], 
        'spr_curr': data['spr_curr'], 
        'spr_dist_to_mean': data['spr_dist_to_mean'], 
        'spr_dist_from_max': data['spr_dist_from_max'], 
        'spr_max_dist': data['spr_max_dist'],
        'beta_hb': data['beta_hb'],
        'beta_wind': data['beta_wind'],
    }

    return d

# %%
trading_history = db_manager.get_table('trading_history', df_type='polars').filter(
    pl.col('open_time') > datetime(2025, 12, 6, 10, tzinfo=ZoneInfo('Europe/Moscow'))
).sort(by='open_time')

# %%
pred_profit_arr = []
real_profit_arr = []

for trade in trading_history.iter_rows(named=True):
    # try:
    token_1 = trade['token_1']
    token_2 = trade['token_2']
    side_1 = trade['side_1']
    side_2 = trade['side_2']
    profit = trade['profit']
    open_price_1 = trade['open_price_1']
    open_price_2 = trade['open_price_2']
    
    open_time = trade['open_time']
    end_time = trade['close_time']
    start_ts = int(datetime.timestamp(open_time))
    end_ts = int(datetime.timestamp(end_time))
    
    
    out_ = 0.25
    tf = '1h'
    
    if open_time < datetime(2025, 12, 2, tzinfo=ZoneInfo('Europe/Moscow')):
        wind = 96
        dist_in = 0.0
        dist_out = 0.0
    else:
        wind = 64
        dist_in = 0.5
        dist_out = 0

    tick_df, agg_df = load_data(token_1, token_2, open_time - timedelta(hours=2), end_time, tf, wind, db_manager)
    tick_df = tick_df.with_columns((pl.col(token_1).log() - pl.col(token_2).log()).alias('log_spread'))
    agg_df = agg_df.with_columns((pl.col(token_1).log() - pl.col(token_2).log()).alias('log_spread'))

    lr_df = create_zscore_df(token_1, token_2, tick_df, agg_df, tf, np.array([wind]), start_ts, 
                             median_length=6, spr_method='lr')
    in_ = lr_df[f'z_score_{wind}_1h'][0]
    
    try:
        open_stats = get_open_time_stats(tick_df, agg_df, token_1, token_2, side_1, side_2, 
                                            open_time, tf, wind, out_, coin_information)
        
        pos_side = 1 if side_1 == 'long' else 2
        data = {'wind': wind, 'open_price_1': open_price_1, 'open_price_2': open_price_2, 'in_': in_, 'out_': out_,
               'dist_in': dist_in, 'dist_out': dist_out, 'pos_side': pos_side}

        stats = calculate_stats(data | open_stats)
        x_test = pl.DataFrame(stats, schema=stat_schema)
        profit_pred = regr_model.predict(x_test.to_numpy())[0]
        sl_pred = clf_sl_model.predict_proba(x_test.to_numpy())[:, 1][0]

        real_profit_arr.append(trade['profit'])
        
        if profit_pred > 0:
            pred_profit_arr.append(trade['profit'])

        print(f'predicted profit: {profit_pred:.2f}, real: {trade['profit']:.2f}; predicted SL: {sl_pred:.2f}, reason: {trade['reason']}; ')
    except IndexError:
        print(token_1, token_2, 'no data')
        continue
    # except Exception:
    #     print(token_1, token_2, 'error')
    #     continue

# %%
np.sum(pred_profit_arr), np.mean(pred_profit_arr), np.std(pred_profit_arr)

# %%
np.sum(real_profit_arr), np.mean(real_profit_arr), np.std(real_profit_arr)

# %%
stats = calculate_stats(data | open_stats)

# %%
dict_keys = set(stats.keys())
schema_keys = set(stat_schema.keys())  # если stat_schema - словарь
# или, если stat_schema - список кортежей (name, dtype)
# schema_keys = {name for name, _ in stat_schema}

print("Ключи только в словаре:", dict_keys - schema_keys)
print("Ключи только в схеме:", schema_keys - dict_keys)
